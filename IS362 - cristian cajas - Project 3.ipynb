# %% [markdown]
# # IS 362 – Project 3
# ## Cristian Cajas
#
#
# ### 1. For your database, you should download and install the appropriate version of the Chinook database for your RDBMS, which is available here, under the downloads tab: https://chinookdatabase.codeplex.com/
#
#     This is complete. I have loaded it onto my SQL server.
#
# ### 2. Your task is to create a pandas DataFrame that displays Customers’ Last Name and First Name, and each customer’s purchased Track names and Album Titles. The information should be sorted by Customer LastName then Customer FirstName. The first five rows of your results should look like this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Below is the data model:
# ![image.png](attachment:image.png)

# %%
# Import the mysql.connector library
import mysql.connector as sql
# Import the pandas library
import pandas as pd

# Connect to the Chinook database version 1.4
sql_connection = sql.connect(host='127.0.0.1', database='chinook', user='manno', password='IS362')

# Save the SQL query to execute
sql_query = ("SELECT \
                customer.LastName AS 'First_Name', \
                customer.FirstName AS 'Last_Name', \
                track.Name AS 'Song_Title', \
                album.Title AS 'Album_Title' \
                FROM customer \
                JOIN invoice \
                    ON customer.CustomerId = invoice.CustomerId \
                JOIN invoiceline \
                    ON invoice.InvoiceId = invoiceline.InvoiceId \
                JOIN track \
                    ON invoiceline.TrackId = track.TrackId \
                JOIN Album \
                    ON track.AlbumId = Album.AlbumId \
                ORDER BY customer.LastName, album.Title ASC, track.name ASC")

# Read the SQL query into a pandas dataframe
customer_songs = pd.read_sql(sql_query, sql_connection)

# %%
# Display the info stored in the dataframe.
customer_songs
# Out:
#       First_Name Last_Name                                         Song_Title  \
# 0        Almeida   Roberto                                  Burden In My Hand
# 1        Almeida   Roberto                                             Flower
# 2        Almeida   Roberto                                  Jesus Christ Pose
# 3        Almeida   Roberto                            The Day I Tried To Live
# 4        Almeida   Roberto                                              Dance
# 5        Almeida   Roberto                                          Vai Valer
# 6        Almeida   Roberto                                      Amor De Muito
# 7        Almeida   Roberto                                       Mateus Enter
# 8        Almeida   Roberto                                      Samba Do Lado
# 9        Almeida   Roberto                              Um Satélite Na Cabeça
# 10       Almeida   Roberto                                           Mundaréu
# 11       Almeida   Roberto                          Banditismo Por Uma Questa
# 12       Almeida   Roberto                          Maracatu De Tiro Certeiro
# 13       Almeida   Roberto                                          Aos Leões
# 14       Almeida   Roberto                                           Demorou!
# 15       Almeida   Roberto                                              Intro
# 16       Almeida   Roberto                               Scentless Apprentice
# 17       Almeida   Roberto                                   Fool In The Rain
# 18       Almeida   Roberto                                     In The Evening
# 19       Almeida   Roberto                             Caso Você Queira Saber
# 20       Almeida   Roberto  Saudade Dos Aviões Da Panair (Conversando No Bar)
# 21       Almeida   Roberto                                     Meu Caro Amigo
# 22       Almeida   Roberto                                   Morena De Angola
# 23       Almeida   Roberto                                         Vai Passar
# 24       Almeida   Roberto                                    Home Sweet Home
# 25       Almeida   Roberto                                           In Bloom
# 26       Almeida   Roberto                                         On A Plain
# 27       Almeida   Roberto                             Nossa Gente (Avisa Là)
# 28       Almeida   Roberto                                     Revolta Olodum
# 29       Almeida   Roberto                                    Refavela (Live)
# ...          ...       ...                                                ...
# 2210  Zimmermann      Fynn                                     Laguna Sunrise
# 2211  Zimmermann      Fynn                                         Proud Mary
# 2212  Zimmermann      Fynn                                            Susie Q
# 2213  Zimmermann      Fynn                                         Ozone Baby
# 2214  Zimmermann      Fynn                                 We're Gonna Groove
# 2215  Zimmermann      Fynn                                               Açai
# 2216  Zimmermann      Fynn                                               Azul
